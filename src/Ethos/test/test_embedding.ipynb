# %%
import ollama

ETHOS_SERVER_IP = "192.168.40.54"
# 포트가 11434가 아닌 11435인 점에 주의하세요!
client = ollama.Client(host=f"http://{ETHOS_SERVER_IP}:11435")

def test_embedding_generation():
    print(f"--- Testing Embedding Generation ---")
    try:
        response = client.embeddings(model="nomic-embed-text:latest", prompt="Hello world")
        print("Success!")
    except Exception as e:
        print(f"Error: {e}")

test_embedding_generation()
# Out:
# --- Testing Embedding Generation ---
# Success!
